# %% [markdown]
# # Demo March 13
# Baseline vs Defended on small subset.

# %%
# !bash ../scripts/run_baseline.sh

# %%
# !bash ../scripts/run_defended.sh

# %%
# !python3 ../scripts/summarize_results.py
